# %%
#Setup Librearies
import os
import torch
import glob
import torchvision
import pathlib
import torch
import numpy as np
import torch.nn as nn
from PIL import Image
from torch import flatten
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.autograd import Variable

# %%
#Check CUDA Usage
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
#Transformers
transformer = transforms.Compose([
  transforms.Resize((250,250)),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize([0.5,0.5,0.5],
                       [0.5,0.5,0.5])
])

# %%
#DataLoaders
train_path = './archive/train/'
validation_path = './archive/valid/'
train_loader = DataLoader(
    torchvision.datasets.ImageFolder(train_path, transform=transformer),
    batch_size=200, shuffle=True
)
validation_loader = DataLoader(
    torchvision.datasets.ImageFolder(validation_path, transform=transformer),
    batch_size=200, shuffle=True
)

# %%
#Categories
root = pathlib.Path(train_path)
classes = sorted([image.name.split('/')[-1] for image in root.iterdir()])

# %%
print(classes)
# Out:
# 75

# %%
#CNN Network
class ConvNet(nn.Module):
    def __init__(self, num_classes=75):
        super(ConvNet, self).__init__()
        
        ## FEATURE 1
        #Inpupt Shape = (256, 3, 150, 150)
        self.conv1=nn.Conv2d(in_channels=3, out_channels=12, kernel_size=(5, 5))
        #Shape = (256, 12, 150, 150)
        self.bn1=nn.BatchNorm2d(num_features=12)
        #Shape = (256, 12, 150, 150)
        self.relu1=nn.ReLU()
        #Shape = (256, 12, 150, 150)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        #Shape = (256, 12, 75, 75)
        
        ## FEATURE 2
        self.conv2=nn.Conv2d(in_channels=12, out_channels=32, kernel_size=(5, 5))
        #Shape = (256, 20, 75, 75)
        self.bn2=nn.BatchNorm2d(num_features=32)
        #Shape = (256, 20, 75, 75)
        self.relu2=nn.ReLU()
        #Shape = (256, 20, 75, 75)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        ## FEATURE 3
        self.conv3=nn.Conv2d(in_channels=32, out_channels=50, kernel_size=(2, 2))
        #Shape = (256, 32, 75, 75)
        self.bn3=nn.BatchNorm2d(num_features=50)
        self.relu3=nn.ReLU()
        #Shape = (256, 32, 75, 75)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        ## FLATTEN
        self.fc1=nn.Linear(in_features=29*29*50, out_features=1000)
        self.relu4=nn.ReLU()
        
        self.fc2=nn.Linear(in_features=1000, out_features=num_classes)
        
    def forward(self, input):
        output = self.conv1 ( input )
        output = self.bn1 ( output )
        output = self.relu1 ( output )
        output = self.pool1 ( output )

        output = self.conv2 ( output )
        output = self.bn2 ( output )
        output = self.relu2 ( output )
        output = self.pool2 ( output )

        output = self.conv3 ( output )
        output = self.bn3 ( output )
        output = self.relu3 ( output )
        output = self.pool3 ( output )
        
        output = flatten(output, 1)
        output = self.fc1(output)
        output = self.relu4(output)
        
        output = self.fc2(output)

        return output

# %%
model = ConvNet().to(device)

# %%
#Optmizer and Loss Function
optimizer = Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
loss_function = nn.CrossEntropyLoss()

# %%
num_epochs = 50

# %%
train_count=len(glob.glob(train_path+'/**/*.jpg'))
validation_count=len(glob.glob(validation_path+'/**/*.jpg'))

# %%
print(train_count, validation_count)
# Out:
# 9285 375

# %%
#Model Training and saving best model
best_accuracy = 0.00
for epoch in range(num_epochs):
    #Evaluation and training on train dataset
    model.train()
    train_accuracy = 0.00
    train_loss = 0.00
    
    for i, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        
        outputs = model(images)
        loss=loss_function(outputs,labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.cpu().data*images.size(0)
        _, predicition = torch.max(outputs.data, 1)
        
        train_accuracy += int(torch.sum(predicition==labels.data))
    
    train_accuracy=train_accuracy/train_count
    train_loss=train_loss/train_count
    
    #Evaluation on testing dataset
    model.eval()
    
    validation_accuracy = 0.00
    for i, (images, labels) in enumerate(validation_loader):
        optimizer.zero_grad()
        
        outputs = model(images)
        
        _, predicition = torch.max(outputs.data, 1)
        validation_accuracy += int(torch.sum(predicition==labels.data))
        
    validation_accuracy=validation_accuracy/validation_count
    
    print(f'Epoch: {epoch} Train Loss: {int(train_loss)} Train Accuracy: {train_accuracy} Validation Accuracy: {validation_accuracy}')
    
    #Save best model
    if validation_accuracy > best_accuracy:
        torch.save(model.state_dict(), 'best_checkpoint.model')
        best_accuracy = validation_accuracy
# Out:
# Epoch: 0 Train Loss: 12 Train Accuracy: 0.06225094238018309 Validation Accuracy: 0.12
# Epoch: 1 Train Loss: 3 Train Accuracy: 0.17705977382875607 Validation Accuracy: 0.2693333333333333
# Epoch: 2 Train Loss: 2 Train Accuracy: 0.3155627355950458 Validation Accuracy: 0.368
# Epoch: 3 Train Loss: 2 Train Accuracy: 0.4355411954765751 Validation Accuracy: 0.44533333333333336
# Epoch: 4 Train Loss: 1 Train Accuracy: 0.5224555735056543 Validation Accuracy: 0.536
# Epoch: 5 Train Loss: 1 Train Accuracy: 0.5961227786752827 Validation Accuracy: 0.56
# Epoch: 6 Train Loss: 1 Train Accuracy: 0.6693591814754981 Validation Accuracy: 0.6293333333333333
# Epoch: 7 Train Loss: 0 Train Accuracy: 0.722778675282714 Validation Accuracy: 0.6666666666666666
# Epoch: 8 Train Loss: 0 Train Accuracy: 0.7766289714593431 Validation Accuracy: 0.6346666666666667
# Epoch: 9 Train Loss: 0 Train Accuracy: 0.8210016155088853 Validation Accuracy: 0.6426666666666667
# Epoch: 10 Train Loss: 0 Train Accuracy: 0.8578352180936996 Validation Accuracy: 0.7173333333333334
# Epoch: 11 Train Loss: 0 Train Accuracy: 0.8879913839526118 Validation Accuracy: 0.6773333333333333
# Epoch: 12 Train Loss: 0 Train Accuracy: 0.9111470113085622 Validation Accuracy: 0.6986666666666667
# Epoch: 13 Train Loss: 0 Train Accuracy: 0.9340872374798062 Validation Accuracy: 0.7013333333333334
# Epoch: 14 Train Loss: 0 Train Accuracy: 0.9520732364028002 Validation Accuracy: 0.7253333333333334
# Epoch: 15 Train Loss: 0 Train Accuracy: 0.9638126009693053 Validation Accuracy: 0.7173333333333334
# Epoch: 16 Train Loss: 0 Train Accuracy: 0.9787829833064082 Validation Accuracy: 0.7173333333333334
# Epoch: 17 Train Loss: 0 Train Accuracy: 0.9835218093699515 Validation Accuracy: 0.7546666666666667
# Epoch: 18 Train Loss: 0 Train Accuracy: 0.9884760366182014 Validation Accuracy: 0.7226666666666667
# Epoch: 19 Train Loss: 0 Train Accuracy: 0.9915993537964459 Validation Accuracy: 0.712
# Epoch: 20 Train Loss: 0 Train Accuracy: 0.9961227786752828 Validation Accuracy: 0.736
# Epoch: 21 Train Loss: 0 Train Accuracy: 0.9978459881529348 Validation Accuracy: 0.7306666666666667
# Epoch: 22 Train Loss: 0 Train Accuracy: 0.9988152934841141 Validation Accuracy: 0.7333333333333333
# Epoch: 23 Train Loss: 0 Train Accuracy: 0.9992460958535272 Validation Accuracy: 0.752
# Epoch: 24 Train Loss: 0 Train Accuracy: 0.9990306946688207 Validation Accuracy: 0.744
# Epoch: 25 Train Loss: 0 Train Accuracy: 0.9990306946688207 Validation Accuracy: 0.7413333333333333
# Epoch: 26 Train Loss: 0 Train Accuracy: 0.9965535810446957 Validation Accuracy: 0.7413333333333333
# Epoch: 27 Train Loss: 0 Train Accuracy: 0.9988152934841141 Validation Accuracy: 0.7466666666666667
# Epoch: 28 Train Loss: 0 Train Accuracy: 0.9992460958535272 Validation Accuracy: 0.7546666666666667
# Epoch: 29 Train Loss: 0 Train Accuracy: 0.9989229940764675 Validation Accuracy: 0.728
# Epoch: 30 Train Loss: 0 Train Accuracy: 0.9984921917070544 Validation Accuracy: 0.7386666666666667
# Epoch: 31 Train Loss: 0 Train Accuracy: 0.9997845988152935 Validation Accuracy: 0.736
# Epoch: 32 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.744
# Epoch: 33 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.7333333333333333
# Epoch: 34 Train Loss: 0 Train Accuracy: 0.9998922994076468 Validation Accuracy: 0.7466666666666667
# Epoch: 35 Train Loss: 0 Train Accuracy: 0.9998922994076468 Validation Accuracy: 0.736
# Epoch: 36 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.7386666666666667
# Epoch: 37 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.744
# Epoch: 38 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.736
# Epoch: 39 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.744
# Epoch: 40 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.7413333333333333
# Epoch: 41 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.7573333333333333
# Epoch: 42 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.752
# Epoch: 43 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.744
# Epoch: 44 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.7493333333333333
# Epoch: 45 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.736
# Epoch: 46 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.7413333333333333
# Epoch: 47 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.752
# Epoch: 48 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.7386666666666667
# Epoch: 49 Train Loss: 0 Train Accuracy: 1.0 Validation Accuracy: 0.7413333333333333

# %%
# Test NN Setup
checkpoint = torch.load('best_checkpoint.model')
model = ConvNet()
model.load_state_dict(checkpoint)
model.eval()

# %%
#Define Test Path
test_path = './archive/test/'

# %%
# Test Funtion
def test(img_path, transformer):
    image = Image.open(img_path)
    
    image_tensor = transformer(image).float()
    
    image_tensor = image_tensor.unsqueeze_(0)
    
    input = Variable(image_tensor)
    
    output = model(input)
    
    index = output.data.numpy().argmax()
    
    pred=classes[index]
    
    return pred

# %%
images_path=glob.glob(test_path+'/**/*.jpg')

# %%
# Test flux
pred_dict = dict()

for i in images_path:
    pred_dict[i[i[i.rfind('/')+1:].rfind('/')+1:]] = test(i, transformer)

pred_dict
# Out:
# {'./archive/test/CAIRNS BIRDWING/5.jpg': 'CAIRNS BIRDWING',
#  './archive/test/CAIRNS BIRDWING/2.jpg': 'CAIRNS BIRDWING',
#  './archive/test/CAIRNS BIRDWING/4.jpg': 'CAIRNS BIRDWING',
#  './archive/test/CAIRNS BIRDWING/3.jpg': 'CAIRNS BIRDWING',
#  './archive/test/CAIRNS BIRDWING/1.jpg': 'CAIRNS BIRDWING',
#  './archive/test/PURPLISH COPPER/5.jpg': 'SILVER SPOT SKIPPER',
#  './archive/test/PURPLISH COPPER/2.jpg': 'BROWN SIPROETA',
#  './archive/test/PURPLISH COPPER/4.jpg': 'BLUE MORPHO',
#  './archive/test/PURPLISH COPPER/3.jpg': 'SLEEPY ORANGE',
#  './archive/test/PURPLISH COPPER/1.jpg': 'PURPLISH COPPER',
#  './archive/test/CHESTNUT/5.jpg': 'CHESTNUT',
#  './archive/test/CHESTNUT/2.jpg': 'CHESTNUT',
#  './archive/test/CHESTNUT/4.jpg': 'COMMON BANDED AWL',
#  './archive/test/CHESTNUT/3.jpg': 'CHESTNUT',
#  './archive/test/CHESTNUT/1.jpg': 'CHESTNUT',
#  './archive/test/EASTERN DAPPLE WHITE/5.jpg': 'EASTERN DAPPLE WHITE',
#  './archive/test/EASTERN DAPPLE WHITE/2.jpg': 'LARGE MARBLE',
#  './archive/test/EASTERN DAPPLE WHITE/4.jpg': 'EASTERN DAPPLE WHITE',
#  './archive/test/EASTERN DAPPLE WHITE/3.jpg': 'LARGE MARBLE',
#  './archive/test/EASTERN DAPPLE WHITE/1.jpg': 'EASTERN DAPPLE WHITE',
#  './archive/test/MILBERTS TORTOISESHELL/5.jpg': 'MILBERTS TORTOISESHELL',
#  './archive/test/MILBERTS TORTOISESHELL/2.jpg': 'MOURNING CLOAK',
#  './archive/test/MILBERTS TORTOISESHELL/4.jpg': 'MILBERTS TORTOISESHELL',
#  './archive/test/MILBERTS TORTOISESHELL/3.jpg': 'MILBERTS TORTOISESHELL',
#  './archive/test/MILBERTS TORTOISESHELL/1.jpg': 'MOURNING CLOAK',
#  './archive/test/AMERICAN SNOOT/5.jpg': 'PINE WHITE',
#  './archive/test/AMERICAN SNOOT/2.jpg': 'AMERICAN SNOOT',
#  './archive/test/AMERICAN SNOOT/4.jpg': 'AMERICAN SNOOT',
#  './archive/test/AMERICAN SNOOT/3.jpg': 'COMMON BANDED AWL',
#  './archive/test/AMERICAN SNOOT/1.jpg': 'AMERICAN SNOOT',
#  './archive/test/ORANGE OAKLEAF/5.jpg': 'ORANGE OAKLEAF',
#  './archive/test/ORANGE OAKLEAF/2.jpg': 'ORANGE OAKLEAF',
#  './archive/test/ORANGE OAKLEAF/4.jpg': 'COMMON BANDED AWL',
#  './archive/test/ORANGE OAKLEAF/3.jpg': 'MESTRA',
#  './archive/test/ORANGE OAKLEAF/1.jpg': 'ORANGE OAKLEAF',
#  './archive/test/INDRA SWALLOW/5.jpg': 'INDRA SWALLOW',
#  './archive/test/INDRA SWALLOW/2.jpg': 'INDRA SWALLOW',
#  './archive/test/INDRA SWALLOW/4.jpg': 'INDRA SWALLOW',
#  './archive/test/INDRA SWALLOW/3.jpg': 'INDRA SWALLOW',
#  './archive/test/INDRA SWALLOW/1.jpg': 'INDRA SWALLOW',
#  './archive/test/PEACOCK/5.jpg': 'PEACOCK',
#  './archive/test/PEACOCK/2.jpg': 'PEACOCK',
#  './archive/test/PEACOCK/4.jpg': 'PEACOCK',
#  './archive/test/PEACOCK/3.jpg': 'BROWN SIPROETA',
#  './archive/test/PEACOCK/1.jpg': 'PEACOCK',
#  './archive/test/POPINJAY/5.jpg': 'MANGROVE SKIPPER',
#  './archive/test/POPINJAY/2.jpg': 'POPINJAY',
#  './archive/test/POPINJAY/4.jpg': 'POPINJAY',
#  './archive/test/POPINJAY/3.jpg': 'POPINJAY',
#  './archive/test/POPINJAY/1.jpg': 'POPINJAY',
#  './archive/test/EASTERN COMA/5.jpg': 'CRECENT',
#  './archive/test/EASTERN COMA/2.jpg': 'EASTERN COMA',
#  './archive/test/EASTERN COMA/4.jpg': 'EASTERN COMA',
#  './archive/test/EASTERN COMA/3.jpg': 'EASTERN COMA',
#  './archive/test/EASTERN COMA/1.jpg': 'EASTERN COMA',
#  './archive/test/STRAITED QUEEN/5.jpg': 'STRAITED QUEEN',
#  './archive/test/STRAITED QUEEN/2.jpg': 'STRAITED QUEEN',
#  './archive/test/STRAITED QUEEN/4.jpg': 'JULIA',
#  './archive/test/STRAITED QUEEN/3.jpg': 'GREAT EGGFLY',
#  './archive/test/STRAITED QUEEN/1.jpg': 'CRIMSON PATCH',
#  './archive/test/VICEROY/5.jpg': 'VICEROY',
#  './archive/test/VICEROY/2.jpg': 'VICEROY',
#  './archive/test/VICEROY/4.jpg': 'VICEROY',
#  './archive/test/VICEROY/3.jpg': 'VICEROY',
#  './archive/test/VICEROY/1.jpg': 'CRIMSON PATCH',
#  './archive/test/GREY HAIRSTREAK/5.jpg': 'GREY HAIRSTREAK',
#  './archive/test/GREY HAIRSTREAK/2.jpg': 'GREY HAIRSTREAK',
#  './archive/test/GREY HAIRSTREAK/4.jpg': 'GREY HAIRSTREAK',
#  './archive/test/GREY HAIRSTREAK/3.jpg': 'GREY HAIRSTREAK',
#  './archive/test/GREY HAIRSTREAK/1.jpg': 'GREY HAIRSTREAK',
#  './archive/test/COPPER TAIL/5.jpg': 'COPPER TAIL',
#  './archive/test/COPPER TAIL/2.jpg': 'COPPER TAIL',
#  './archive/test/COPPER TAIL/4.jpg': 'PURPLISH COPPER',
#  './archive/test/COPPER TAIL/3.jpg': 'COPPER TAIL',
#  './archive/test/COPPER TAIL/1.jpg': 'ORANGE TIP',
#  './archive/test/GREEN CELLED CATTLEHEART/5.jpg': 'RED POSTMAN',
#  './archive/test/GREEN CELLED CATTLEHEART/2.jpg': 'RED POSTMAN',
#  './archive/test/GREEN CELLED CATTLEHEART/4.jpg': 'METALMARK',
#  './archive/test/GREEN CELLED CATTLEHEART/3.jpg': 'GREEN CELLED CATTLEHEART',
#  './archive/test/GREEN CELLED CATTLEHEART/1.jpg': 'GREEN CELLED CATTLEHEART',
#  './archive/test/PAPER KITE/5.jpg': 'PAPER KITE',
#  './archive/test/PAPER KITE/2.jpg': 'PAPER KITE',
#  './archive/test/PAPER KITE/4.jpg': 'PAPER KITE',
#  './archive/test/PAPER KITE/3.jpg': 'PAPER KITE',
#  './archive/test/PAPER KITE/1.jpg': 'PAPER KITE',
#  './archive/test/WOOD SATYR/5.jpg': 'WOOD SATYR',
#  './archive/test/WOOD SATYR/2.jpg': 'WOOD SATYR',
#  './archive/test/WOOD SATYR/4.jpg': 'WOOD SATYR',
#  './archive/test/WOOD SATYR/3.jpg': 'WOOD SATYR',
#  './archive/test/WOOD SATYR/1.jpg': 'WOOD SATYR',
#  './archive/test/GREAT JAY/5.jpg': 'GREAT JAY',
#  './archive/test/GREAT JAY/2.jpg': 'GREAT JAY',
#  './archive/test/GREAT JAY/4.jpg': 'GREAT JAY',
#  './archive/test/GREAT JAY/3.jpg': 'GREAT JAY',
#  './archive/test/GREAT JAY/1.jpg': 'GREAT JAY',
#  './archive/test/BANDED ORANGE HELICONIAN/5.jpg': 'BANDED ORANGE HELICONIAN',
#  './archive/test/BANDED ORANGE HELICONIAN/2.jpg': 'BANDED ORANGE HELICONIAN',
#  './archive/test/BANDED ORANGE HELICONIAN/4.jpg': 'BANDED ORANGE HELICONIAN',
#  './archive/test/BANDED ORANGE HELICONIAN/3.jpg': 'BANDED ORANGE HELICONIAN',
#  './archive/test/BANDED ORANGE HELICONIAN/1.jpg': 'BANDED ORANGE HELICONIAN',
#  './archive/test/AFRICAN GIANT SWALLOWTAIL/5.jpg': 'AFRICAN GIANT SWALLOWTAIL',
#  './archive/test/AFRICAN GIANT SWALLOWTAIL/2.jpg': 'AFRICAN GIANT SWALLOWTAIL',
#  './archive/test/AFRICAN GIANT SWALLOWTAIL/4.jpg': 'AFRICAN GIANT SWALLOWTAIL',
#  './archive/test/AFRICAN GIANT SWALLOWTAIL/3.jpg': 'AFRICAN GIANT SWALLOWTAIL',
#  './archive/test/AFRICAN GIANT SWALLOWTAIL/1.jpg': 'AFRICAN GIANT SWALLOWTAIL',
#  './archive/test/BLACK HAIRSTREAK/5.jpg': 'BLACK HAIRSTREAK',
#  './archive/test/BLACK HAIRSTREAK/2.jpg': 'BLACK HAIRSTREAK',
#  './archive/test/BLACK HAIRSTREAK/4.jpg': 'BLACK HAIRSTREAK',
#  './archive/test/BLACK HAIRSTREAK/3.jpg': 'BLACK HAIRSTREAK',
#  './archive/test/BLACK HAIRSTREAK/1.jpg': 'BLACK HAIRSTREAK',
#  './archive/test/METALMARK/5.jpg': 'METALMARK',
#  './archive/test/METALMARK/2.jpg': 'METALMARK',
#  './archive/test/METALMARK/4.jpg': 'ATALA',
#  './archive/test/METALMARK/3.jpg': 'ULYSES',
#  './archive/test/METALMARK/1.jpg': 'METALMARK',
#  './archive/test/ZEBRA LONG WING/5.jpg': 'ZEBRA LONG WING',
#  './archive/test/ZEBRA LONG WING/2.jpg': 'ZEBRA LONG WING',
#  './archive/test/ZEBRA LONG WING/4.jpg': 'ZEBRA LONG WING',
#  './archive/test/ZEBRA LONG WING/3.jpg': 'ZEBRA LONG WING',
#  './archive/test/ZEBRA LONG WING/1.jpg': 'ZEBRA LONG WING',
#  './archive/test/AN 88/5.jpg': 'CRECENT',
#  './archive/test/AN 88/2.jpg': 'AN 88',
#  './archive/test/AN 88/4.jpg': 'AN 88',
#  './archive/test/AN 88/3.jpg': 'AN 88',
#  './archive/test/AN 88/1.jpg': 'AN 88',
#  './archive/test/YELLOW SWALLOW TAIL/5.jpg': 'INDRA SWALLOW',
#  './archive/test/YELLOW SWALLOW TAIL/2.jpg': 'YELLOW SWALLOW TAIL',
#  './archive/test/YELLOW SWALLOW TAIL/4.jpg': 'YELLOW SWALLOW TAIL',
#  './archive/test/YELLOW SWALLOW TAIL/3.jpg': 'INDRA SWALLOW',
#  './archive/test/YELLOW SWALLOW TAIL/1.jpg': 'YELLOW SWALLOW TAIL',
#  './archive/test/TROPICAL LEAFWING/5.jpg': 'SLEEPY ORANGE',
#  './archive/test/TROPICAL LEAFWING/2.jpg': 'TROPICAL LEAFWING',
#  './archive/test/TROPICAL LEAFWING/4.jpg': 'TROPICAL LEAFWING',
#  './archive/test/TROPICAL LEAFWING/3.jpg': 'MESTRA',
#  './archive/test/TROPICAL LEAFWING/1.jpg': 'EASTERN PINE ELFIN',
#  './archive/test/SCARCE SWALLOW/5.jpg': 'SCARCE SWALLOW',
#  './archive/test/SCARCE SWALLOW/2.jpg': 'SCARCE SWALLOW',
#  './archive/test/SCARCE SWALLOW/4.jpg': 'SCARCE SWALLOW',
#  './archive/test/SCARCE SWALLOW/3.jpg': 'SCARCE SWALLOW',
#  './archive/test/SCARCE SWALLOW/1.jpg': 'SCARCE SWALLOW',
#  './archive/test/MANGROVE SKIPPER/5.jpg': 'MANGROVE SKIPPER',
#  './archive/test/MANGROVE SKIPPER/2.jpg': 'MANGROVE SKIPPER',
#  './archive/test/MANGROVE SKIPPER/4.jpg': 'COMMON WOOD-NYMPH',
#  './archive/test/MANGROVE SKIPPER/3.jpg': 'MANGROVE SKIPPER',
#  './archive/test/MANGROVE SKIPPER/1.jpg': 'MANGROVE SKIPPER',
#  './archive/test/MONARCH/5.jpg': 'MONARCH',
#  './archive/test/MONARCH/2.jpg': 'MONARCH',
#  './archive/test/MONARCH/4.jpg': 'PAPER KITE',
#  './archive/test/MONARCH/3.jpg': 'MONARCH',
#  './archive/test/MONARCH/1.jpg': 'MONARCH',
#  './archive/test/APPOLLO/5.jpg': 'MESTRA',
#  './archive/test/APPOLLO/2.jpg': 'APPOLLO',
#  './archive/test/APPOLLO/4.jpg': 'APPOLLO',
#  './archive/test/APPOLLO/3.jpg': 'APPOLLO',
#  './archive/test/APPOLLO/1.jpg': 'APPOLLO',
#  './archive/test/BROWN SIPROETA/5.jpg': 'BROWN SIPROETA',
#  './archive/test/BROWN SIPROETA/2.jpg': 'BANDED ORANGE HELICONIAN',
#  './archive/test/BROWN SIPROETA/4.jpg': 'BROWN SIPROETA',
#  './archive/test/BROWN SIPROETA/3.jpg': 'BROWN SIPROETA',
#  './archive/test/BROWN SIPROETA/1.jpg': 'BROWN SIPROETA',
#  './archive/test/JULIA/5.jpg': 'JULIA',
#  './archive/test/JULIA/2.jpg': 'JULIA',
#  './archive/test/JULIA/4.jpg': 'JULIA',
#  './archive/test/JULIA/3.jpg': 'JULIA',
#  './archive/test/JULIA/1.jpg': 'JULIA',
#  './archive/test/ATALA/5.jpg': 'ATALA',
#  './archive/test/ATALA/2.jpg': 'METALMARK',
#  './archive/test/ATALA/4.jpg': 'ATALA',
#  './archive/test/ATALA/3.jpg': 'ATALA',
#  './archive/test/ATALA/1.jpg': 'ATALA',
#  './archive/test/ADONIS/5.jpg': 'ADONIS',
#  './archive/test/ADONIS/2.jpg': 'ADONIS',
#  './archive/test/ADONIS/4.jpg': 'ADONIS',
#  './archive/test/ADONIS/3.jpg': 'ADONIS',
#  './archive/test/ADONIS/1.jpg': 'ADONIS',
#  './archive/test/MOURNING CLOAK/5.jpg': 'MOURNING CLOAK',
#  './archive/test/MOURNING CLOAK/2.jpg': 'MOURNING CLOAK',
#  './archive/test/MOURNING CLOAK/4.jpg': 'MOURNING CLOAK',
#  './archive/test/MOURNING CLOAK/3.jpg': 'MOURNING CLOAK',
#  './archive/test/MOURNING CLOAK/1.jpg': 'MOURNING CLOAK',
#  './archive/test/MALACHITE/5.jpg': 'CAIRNS BIRDWING',
#  './archive/test/MALACHITE/2.jpg': 'MALACHITE',
#  './archive/test/MALACHITE/4.jpg': 'MALACHITE',
#  './archive/test/MALACHITE/3.jpg': 'MALACHITE',
#  './archive/test/MALACHITE/1.jpg': 'GREAT JAY',
#  './archive/test/ULYSES/5.jpg': 'ULYSES',
#  './archive/test/ULYSES/2.jpg': 'ULYSES',
#  './archive/test/ULYSES/4.jpg': 'ULYSES',
#  './archive/test/ULYSES/3.jpg': 'ULYSES',
#  './archive/test/ULYSES/1.jpg': 'ULYSES',
#  './archive/test/CABBAGE WHITE/5.jpg': 'CABBAGE WHITE',
#  './archive/test/CABBAGE WHITE/2.jpg': 'CABBAGE WHITE',
#  './archive/test/CABBAGE WHITE/4.jpg': 'CABBAGE WHITE',
#  './archive/test/CABBAGE WHITE/3.jpg': 'CABBAGE WHITE',
#  './archive/test/CABBAGE WHITE/1.jpg': 'CABBAGE WHITE',
#  './archive/test/RED POSTMAN/5.jpg': 'RED POSTMAN',
#  './archive/test/RED POSTMAN/2.jpg': 'RED POSTMAN',
#  './archive/test/RED POSTMAN/4.jpg': 'RED POSTMAN',
#  './archive/test/RED POSTMAN/3.jpg': 'RED POSTMAN',
#  './archive/test/RED POSTMAN/1.jpg': 'BLUE MORPHO',
#  './archive/test/TWO BARRED FLASHER/5.jpg': 'TWO BARRED FLASHER',
#  './archive/test/TWO BARRED FLASHER/2.jpg': 'TWO BARRED FLASHER',
#  './archive/test/TWO BARRED FLASHER/4.jpg': 'TWO BARRED FLASHER',
#  './archive/test/TWO BARRED FLASHER/3.jpg': 'TWO BARRED FLASHER',
#  './archive/test/TWO BARRED FLASHER/1.jpg': 'TWO BARRED FLASHER',
#  './archive/test/COMMON BANDED AWL/5.jpg': 'COMMON BANDED AWL',
#  './archive/test/COMMON BANDED AWL/2.jpg': 'COMMON BANDED AWL',
#  './archive/test/COMMON BANDED AWL/4.jpg': 'AMERICAN SNOOT',
#  './archive/test/COMMON BANDED AWL/3.jpg': 'COMMON BANDED AWL',
#  './archive/test/COMMON BANDED AWL/1.jpg': 'COMMON WOOD-NYMPH',
#  './archive/test/CRIMSON PATCH/5.jpg': 'CRIMSON PATCH',
#  './archive/test/CRIMSON PATCH/2.jpg': 'CRIMSON PATCH',
#  './archive/test/CRIMSON PATCH/4.jpg': 'CRIMSON PATCH',
#  './archive/test/CRIMSON PATCH/3.jpg': 'CRIMSON PATCH',
#  './archive/test/CRIMSON PATCH/1.jpg': 'ATALA',
#  './archive/test/RED ADMIRAL/5.jpg': 'RED ADMIRAL',
#  './archive/test/RED ADMIRAL/2.jpg': 'RED ADMIRAL',
#  './archive/test/RED ADMIRAL/4.jpg': 'RED ADMIRAL',
#  './archive/test/RED ADMIRAL/3.jpg': 'MOURNING CLOAK',
#  './archive/test/RED ADMIRAL/1.jpg': 'RED ADMIRAL',
#  './archive/test/BLUE MORPHO/5.jpg': 'BLUE MORPHO',
#  './archive/test/BLUE MORPHO/2.jpg': 'BLUE MORPHO',
#  './archive/test/BLUE MORPHO/4.jpg': 'BLUE MORPHO',
#  './archive/test/BLUE MORPHO/3.jpg': 'ORCHARD SWALLOW',
#  './archive/test/BLUE MORPHO/1.jpg': 'BLUE MORPHO',
#  './archive/test/ELBOWED PIERROT/5.jpg': 'ELBOWED PIERROT',
#  './archive/test/ELBOWED PIERROT/2.jpg': 'ELBOWED PIERROT',
#  './archive/test/ELBOWED PIERROT/4.jpg': 'ELBOWED PIERROT',
#  './archive/test/ELBOWED PIERROT/3.jpg': 'ELBOWED PIERROT',
#  './archive/test/ELBOWED PIERROT/1.jpg': 'IPHICLUS SISTER',
#  './archive/test/ORCHARD SWALLOW/5.jpg': 'ORCHARD SWALLOW',
#  './archive/test/ORCHARD SWALLOW/2.jpg': 'ORCHARD SWALLOW',
#  './archive/test/ORCHARD SWALLOW/4.jpg': 'ORCHARD SWALLOW',
#  './archive/test/ORCHARD SWALLOW/3.jpg': 'ORCHARD SWALLOW',
#  './archive/test/ORCHARD SWALLOW/1.jpg': 'ELBOWED PIERROT',
#  './archive/test/BECKERS WHITE/5.jpg': 'BECKERS WHITE',
#  './archive/test/BECKERS WHITE/2.jpg': 'BECKERS WHITE',
#  './archive/test/BECKERS WHITE/4.jpg': 'BECKERS WHITE',
#  './archive/test/BECKERS WHITE/3.jpg': 'BECKERS WHITE',
#  './archive/test/BECKERS WHITE/1.jpg': 'BECKERS WHITE',
#  './archive/test/COMMON WOOD-NYMPH/5.jpg': 'COMMON WOOD-NYMPH',
#  './archive/test/COMMON WOOD-NYMPH/2.jpg': 'COMMON WOOD-NYMPH',
#  './archive/test/COMMON WOOD-NYMPH/4.jpg': 'COMMON WOOD-NYMPH',
#  './archive/test/COMMON WOOD-NYMPH/3.jpg': 'COMMON WOOD-NYMPH',
#  './archive/test/COMMON WOOD-NYMPH/1.jpg': 'COMMON WOOD-NYMPH',
#  './archive/test/SOOTYWING/5.jpg': 'SOOTYWING',
#  './archive/test/SOOTYWING/2.jpg': 'SOOTYWING',
#  './archive/test/SOOTYWING/4.jpg': 'SOOTYWING',
#  './archive/test/SOOTYWING/3.jpg': 'SOOTYWING',
#  './archive/test/SOOTYWING/1.jpg': 'GREAT EGGFLY',
#  './archive/test/RED CRACKER/5.jpg': 'RED CRACKER',
#  './archive/test/RED CRACKER/2.jpg': 'RED CRACKER',
#  './archive/test/RED CRACKER/4.jpg': 'DANAID EGGFLY',
#  './archive/test/RED CRACKER/3.jpg': 'RED CRACKER',
#  './archive/test/RED CRACKER/1.jpg': 'RED CRACKER',
#  './archive/test/CRECENT/5.jpg': 'CRECENT',
#  './archive/test/CRECENT/2.jpg': 'CRECENT',
#  './archive/test/CRECENT/4.jpg': 'CRECENT',
#  './archive/test/CRECENT/3.jpg': 'CRECENT',
#  './archive/test/CRECENT/1.jpg': 'BANDED ORANGE HELICONIAN',
#  './archive/test/RED SPOTTED PURPLE/5.jpg': 'RED SPOTTED PURPLE',
#  './archive/test/RED SPOTTED PURPLE/2.jpg': 'RED SPOTTED PURPLE',
#  './archive/test/RED SPOTTED PURPLE/4.jpg': 'RED SPOTTED PURPLE',
#  './archive/test/RED SPOTTED PURPLE/3.jpg': 'RED SPOTTED PURPLE',
#  './archive/test/RED SPOTTED PURPLE/1.jpg': 'RED SPOTTED PURPLE',
#  './archive/test/QUESTION MARK/5.jpg': 'QUESTION MARK',
#  './archive/test/QUESTION MARK/2.jpg': 'QUESTION MARK',
#  './archive/test/QUESTION MARK/4.jpg': 'EASTERN COMA',
#  './archive/test/QUESTION MARK/3.jpg': 'QUESTION MARK',
#  './archive/test/QUESTION MARK/1.jpg': 'QUESTION MARK',
#  './archive/test/ORANGE TIP/5.jpg': 'ORANGE TIP',
#  './archive/test/ORANGE TIP/2.jpg': 'ORANGE TIP',
#  './archive/test/ORANGE TIP/4.jpg': 'ORANGE TIP',
#  './archive/test/ORANGE TIP/3.jpg': 'ORANGE TIP',
#  './archive/test/ORANGE TIP/1.jpg': 'ORANGE TIP',
#  './archive/test/GREAT EGGFLY/5.jpg': 'BLUE SPOTTED CROW',
#  './archive/test/GREAT EGGFLY/2.jpg': 'RED CRACKER',
#  './archive/test/GREAT EGGFLY/4.jpg': 'GREAT EGGFLY',
#  './archive/test/GREAT EGGFLY/3.jpg': 'GREAT EGGFLY',
#  './archive/test/GREAT EGGFLY/1.jpg': 'EASTERN PINE ELFIN',
#  './archive/test/SLEEPY ORANGE/5.jpg': 'SLEEPY ORANGE',
#  './archive/test/SLEEPY ORANGE/2.jpg': 'CLOUDED SULPHUR',
#  './archive/test/SLEEPY ORANGE/4.jpg': 'SLEEPY ORANGE',
#  './archive/test/SLEEPY ORANGE/3.jpg': 'SOUTHERN DOGFACE',
#  './archive/test/SLEEPY ORANGE/1.jpg': 'SLEEPY ORANGE',
#  './archive/test/MESTRA/5.jpg': 'MESTRA',
#  './archive/test/MESTRA/2.jpg': 'MESTRA',
#  './archive/test/MESTRA/4.jpg': 'CABBAGE WHITE',
#  './archive/test/MESTRA/3.jpg': 'MESTRA',
#  './archive/test/MESTRA/1.jpg': 'MESTRA',
#  './archive/test/SOUTHERN DOGFACE/5.jpg': 'CLOUDED SULPHUR',
#  './archive/test/SOUTHERN DOGFACE/2.jpg': 'SOUTHERN DOGFACE',
#  './archive/test/SOUTHERN DOGFACE/4.jpg': 'CLEOPATRA',
#  './archive/test/SOUTHERN DOGFACE/3.jpg': 'SOUTHERN DOGFACE',
#  './archive/test/SOUTHERN DOGFACE/1.jpg': 'SOUTHERN DOGFACE',
#  './archive/test/EASTERN PINE ELFIN/5.jpg': 'EASTERN PINE ELFIN',
#  './archive/test/EASTERN PINE ELFIN/2.jpg': 'EASTERN PINE ELFIN',
#  './archive/test/EASTERN PINE ELFIN/4.jpg': 'EASTERN PINE ELFIN',
#  './archive/test/EASTERN PINE ELFIN/3.jpg': 'COMMON WOOD-NYMPH',
#  './archive/test/EASTERN PINE ELFIN/1.jpg': 'EASTERN PINE ELFIN',
#  './archive/test/PINE WHITE/5.jpg': 'PINE WHITE',
#  './archive/test/PINE WHITE/2.jpg': 'PINE WHITE',
#  './archive/test/PINE WHITE/4.jpg': 'CLODIUS PARNASSIAN',
#  './archive/test/PINE WHITE/3.jpg': 'PINE WHITE',
#  './archive/test/PINE WHITE/1.jpg': 'PINE WHITE',
#  './archive/test/CLODIUS PARNASSIAN/5.jpg': 'APPOLLO',
#  './archive/test/CLODIUS PARNASSIAN/2.jpg': 'APPOLLO',
#  './archive/test/CLODIUS PARNASSIAN/4.jpg': 'CLODIUS PARNASSIAN',
#  './archive/test/CLODIUS PARNASSIAN/3.jpg': 'APPOLLO',
#  './archive/test/CLODIUS PARNASSIAN/1.jpg': 'BECKERS WHITE',
#  './archive/test/PIPEVINE SWALLOW/5.jpg': 'ORCHARD SWALLOW',
#  './archive/test/PIPEVINE SWALLOW/2.jpg': 'PIPEVINE SWALLOW',
#  './archive/test/PIPEVINE SWALLOW/4.jpg': 'PIPEVINE SWALLOW',
#  './archive/test/PIPEVINE SWALLOW/3.jpg': 'PIPEVINE SWALLOW',
#  './archive/test/PIPEVINE SWALLOW/1.jpg': 'RED SPOTTED PURPLE',
#  './archive/test/BLUE SPOTTED CROW/5.jpg': 'BLUE SPOTTED CROW',
#  './archive/test/BLUE SPOTTED CROW/2.jpg': 'BLUE SPOTTED CROW',
#  './archive/test/BLUE SPOTTED CROW/4.jpg': 'BLUE SPOTTED CROW',
#  './archive/test/BLUE SPOTTED CROW/3.jpg': 'BLUE SPOTTED CROW',
#  './archive/test/BLUE SPOTTED CROW/1.jpg': 'POPINJAY',
#  './archive/test/CHECQUERED SKIPPER/5.jpg': 'CHECQUERED SKIPPER',
#  './archive/test/CHECQUERED SKIPPER/2.jpg': 'CHECQUERED SKIPPER',
#  './archive/test/CHECQUERED SKIPPER/4.jpg': 'CHECQUERED SKIPPER',
#  './archive/test/CHECQUERED SKIPPER/3.jpg': 'CHECQUERED SKIPPER',
#  './archive/test/CHECQUERED SKIPPER/1.jpg': 'CRECENT',
#  './archive/test/CLEOPATRA/5.jpg': 'SLEEPY ORANGE',
#  './archive/test/CLEOPATRA/2.jpg': 'SLEEPY ORANGE',
#  './archive/test/CLEOPATRA/4.jpg': 'PURPLISH COPPER',
#  './archive/test/CLEOPATRA/3.jpg': 'CLEOPATRA',
#  './archive/test/CLEOPATRA/1.jpg': 'CLOUDED SULPHUR',
#  './archive/test/IPHICLUS SISTER/5.jpg': 'IPHICLUS SISTER',
#  './archive/test/IPHICLUS SISTER/2.jpg': 'IPHICLUS SISTER',
#  './archive/test/IPHICLUS SISTER/4.jpg': 'SILVER SPOT SKIPPER',
#  './archive/test/IPHICLUS SISTER/3.jpg': 'IPHICLUS SISTER',
#  './archive/test/IPHICLUS SISTER/1.jpg': 'IPHICLUS SISTER',
#  './archive/test/SILVER SPOT SKIPPER/5.jpg': 'SILVER SPOT SKIPPER',
#  './archive/test/SILVER SPOT SKIPPER/2.jpg': 'SILVER SPOT SKIPPER',
#  './archive/test/SILVER SPOT SKIPPER/4.jpg': 'SILVER SPOT SKIPPER',
#  './archive/test/SILVER SPOT SKIPPER/3.jpg': 'SILVER SPOT SKIPPER',
#  './archive/test/SILVER SPOT SKIPPER/1.jpg': 'SILVER SPOT SKIPPER',
#  './archive/test/PAINTED LADY/5.jpg': 'PAINTED LADY',
#  './archive/test/PAINTED LADY/2.jpg': 'STRAITED QUEEN',
#  './archive/test/PAINTED LADY/4.jpg': 'PAINTED LADY',
#  './archive/test/PAINTED LADY/3.jpg': 'CRECENT',
#  './archive/test/PAINTED LADY/1.jpg': 'PAINTED LADY',
#  './archive/test/BANDED PEACOCK/5.jpg': 'BANDED PEACOCK',
#  './archive/test/BANDED PEACOCK/2.jpg': 'BANDED PEACOCK',
#  './archive/test/BANDED PEACOCK/4.jpg': 'BANDED PEACOCK',
#  './archive/test/BANDED PEACOCK/3.jpg': 'BANDED PEACOCK',
#  './archive/test/BANDED PEACOCK/1.jpg': 'BANDED PEACOCK',
#  './archive/test/CLOUDED SULPHUR/5.jpg': 'SOUTHERN DOGFACE',
#  './archive/test/CLOUDED SULPHUR/2.jpg': 'CLOUDED SULPHUR',
#  './archive/test/CLOUDED SULPHUR/4.jpg': 'SOUTHERN DOGFACE',
#  './archive/test/CLOUDED SULPHUR/3.jpg': 'SOUTHERN DOGFACE',
#  './archive/test/CLOUDED SULPHUR/1.jpg': 'CLOUDED SULPHUR',
#  './archive/test/DANAID EGGFLY/5.jpg': 'RED CRACKER',
#  './archive/test/DANAID EGGFLY/2.jpg': 'DANAID EGGFLY',
#  './archive/test/DANAID EGGFLY/4.jpg': 'ZEBRA LONG WING',
#  './archive/test/DANAID EGGFLY/3.jpg': 'GREAT EGGFLY',
#  './archive/test/DANAID EGGFLY/1.jpg': 'DANAID EGGFLY',
#  './archive/test/GOLD BANDED/5.jpg': 'GOLD BANDED',
#  './archive/test/GOLD BANDED/2.jpg': 'GOLD BANDED',
#  './archive/test/GOLD BANDED/4.jpg': 'GOLD BANDED',
#  './archive/test/GOLD BANDED/3.jpg': 'GOLD BANDED',
#  './archive/test/GOLD BANDED/1.jpg': 'GOLD BANDED',
#  './archive/test/PURPLE HAIRSTREAK/5.jpg': 'BLUE MORPHO',
#  './archive/test/PURPLE HAIRSTREAK/2.jpg': 'ULYSES',
#  './archive/test/PURPLE HAIRSTREAK/4.jpg': 'PIPEVINE SWALLOW',
#  './archive/test/PURPLE HAIRSTREAK/3.jpg': 'PURPLE HAIRSTREAK',
#  './archive/test/PURPLE HAIRSTREAK/1.jpg': 'PURPLE HAIRSTREAK',
#  './archive/test/LARGE MARBLE/5.jpg': 'ORANGE TIP',
#  './archive/test/LARGE MARBLE/2.jpg': 'LARGE MARBLE',
#  './archive/test/LARGE MARBLE/4.jpg': 'LARGE MARBLE',
#  './archive/test/LARGE MARBLE/3.jpg': 'CABBAGE WHITE',
#  './archive/test/LARGE MARBLE/1.jpg': 'BECKERS WHITE'}

# %%
# Use the NN
use_path = './archive/6 images/'
use_images_path=glob.glob(use_path+'/*.jpg')

# %%
# Use flux
pred_dict = dict()

for i in use_images_path:
    pred_dict[i[i.rfind('/')+1:]] = test(i, transformer)

pred_dict
# Out:
# {'5.jpg': 'ADONIS',
#  '2.jpg': 'ADONIS',
#  '4.jpg': 'ADONIS',
#  '3.jpg': 'ADONIS',
#  '6.jpg': 'AN 88',
#  '1.jpg': 'ADONIS',
#  'Danaidae_Monarch_John_Jackman-M.jpg': 'MONARCH',
#  'Painted Lady UPUR1_Ian H Leach.jpg': 'CHECQUERED SKIPPER'}
